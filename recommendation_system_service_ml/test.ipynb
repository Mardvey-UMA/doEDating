# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print(device)
# Out:
# cuda

# %%
import json
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import normalize
from sentence_transformers import SentenceTransformer
import stanza
from dataclasses import dataclass
from typing import List, Dict, Tuple
from interests_embeddings import ie
interest_embeddings = ie

nlp = stanza.Pipeline('ru', processors='tokenize,ner')
# Out:
# 2024-12-24 18:13:51 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json: 216kB [00:00, 13.6MB/s]
# 2024-12-24 18:13:52 INFO: Loading these models for language: ru (Russian):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | syntagrus |
# | ner       | wikiner   |
# =========================
#
# 2024-12-24 18:13:52 INFO: Using device: cuda
# 2024-12-24 18:13:52 INFO: Loading: tokenize
# /home/matvey/anaconda3/envs/res_sys_ml_kafka/lib/python3.9/site-packages/stanza/models/tokenization/trainer.py:82: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2024-12-24 18:13:52 INFO: Loading: ner
# 2024-12-24 18:13:54 INFO: Done loading processors!

# %%
model = SentenceTransformer("DeepPavlov/rubert-base-cased")
#model = SentenceTransformer('sberbank-ai/sbert_large_nlu_ru')
# Out:
# Downloading:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Downloading:   0%|          | 111k/714M [00:00<10:58, 1.08MB/s]
# Downloading:   0%|          | 520k/714M [00:00<04:12, 2.83MB/s]
# Downloading:   0%|          | 1.25M/714M [00:00<02:42, 4.40MB/s]
# Downloading:   0%|          | 2.43M/714M [00:00<02:04, 5.72MB/s]
# Downloading:   1%|          | 4.81M/714M [00:00<01:04, 11.1MB/s]
# Downloading:   1%|          | 6.00M/714M [00:00<01:06, 10.7MB/s]
# Downloading:   1%|          | 7.31M/714M [00:00<01:02, 11.4MB/s]
# Downloading:   1%|          | 8.50M/714M [00:00<01:01, 11.5MB/s]
# Downloading:   1%|▏         | 9.68M/714M [00:01<01:09, 10.1MB/s]
# Downloading:   2%|▏         | 11.3M/714M [00:01<00:59, 11.9MB/s]
# Downloading:   2%|▏         | 12.6M/714M [00:01<00:59, 11.8MB/s]
# Downloading:   2%|▏         | 13.8M/714M [00:01<01:08, 10.3MB/s]
# Downloading:   2%|▏         | 15.5M/714M [00:01<00:58, 12.0MB/s]
# Downloading:   2%|▏         | 16.8M/714M [00:01<00:58, 11.9MB/s]
# Downloading:   3%|▎         | 18.0M/714M [00:01<00:58, 11.8MB/s]
# Downloading:   3%|▎         | 19.2M/714M [00:01<01:01, 11.2MB/s]
# Downloading:   3%|▎         | 20.6M/714M [00:01<00:59, 11.8MB/s]
# Downloading:   3%|▎         | 21.8M/714M [00:02<00:59, 11.7MB/s]
# Downloading:   3%|▎         | 23.0M/714M [00:02<01:06, 10.3MB/s]
# Downloading:   3%|▎         | 24.6M/714M [00:02<00:57, 12.0MB/s]
# Downloading:   4%|▎         | 25.9M/714M [00:02<00:57, 11.9MB/s]
# Downloading:   4%|▍         | 27.1M/714M [00:02<01:06, 10.4MB/s]
# Downloading:   4%|▍         | 28.8M/714M [00:02<00:56, 12.1MB/s]
# Downloading:   4%|▍         | 30.1M/714M [00:02<00:57, 12.0MB/s]
# Downloading:   4%|▍         | 31.3M/714M [00:02<00:57, 11.9MB/s]
# Downloading:   5%|▍         | 32.6M/714M [00:03<01:00, 11.3MB/s]
# Downloading:   5%|▍         | 33.9M/714M [00:03<00:57, 11.8MB/s]
# Downloading:   5%|▍         | 35.1M/714M [00:03<00:57, 11.7MB/s]
# Downloading:   5%|▌         | 36.3M/714M [00:03<01:05, 10.4MB/s]
# Downloading:   5%|▌         | 37.9M/714M [00:03<00:56, 12.0MB/s]
# Downloading:   5%|▌         | 39.2M/714M [00:03<00:56, 11.9MB/s]
# Downloading:   6%|▌         | 40.4M/714M [00:03<01:04, 10.4MB/s]
# Downloading:   6%|▌         | 42.1M/714M [00:03<00:55, 12.1MB/s]
# Downloading:   6%|▌         | 43.4M/714M [00:03<00:56, 11.9MB/s]
# Downloading:   6%|▌         | 44.6M/714M [00:04<00:56, 11.9MB/s]
# Downloading:   6%|▋         | 45.8M/714M [00:04<00:58, 11.4MB/s]
# Downloading:   7%|▋         | 47.1M/714M [00:04<00:56, 11.7MB/s]
# Downloading:   7%|▋         | 48.2M/714M [00:04<00:56, 11.7MB/s]
# Downloading:   7%|▋         | 49.4M/714M [00:04<01:04, 10.3MB/s]
# Downloading:   7%|▋         | 51.1M/714M [00:04<00:55, 12.0MB/s]
# Downloading:   7%|▋         | 52.3M/714M [00:04<00:55, 11.9MB/s]
# Downloading:   7%|▋         | 53.6M/714M [00:04<00:56, 11.8MB/s]
# Downloading:   8%|▊         | 54.8M/714M [00:04<00:58, 11.4MB/s]
# Downloading:   8%|▊         | 56.0M/714M [00:05<00:56, 11.7MB/s]
# Downloading:   8%|▊         | 57.2M/714M [00:05<00:56, 11.7MB/s]
# Downloading:   8%|▊         | 58.4M/714M [00:05<01:03, 10.3MB/s]
# Downloading:   8%|▊         | 60.0M/714M [00:05<00:54, 12.0MB/s]
# Downloading:   9%|▊         | 61.3M/714M [00:05<00:55, 11.9MB/s]
# Downloading:   9%|▊         | 62.5M/714M [00:05<00:55, 11.8MB/s]
# Downloading:   9%|▉         | 63.7M/714M [00:05<00:56, 11.4MB/s]
# Downloading:   9%|▉         | 64.9M/714M [00:05<00:55, 11.6MB/s]
# Downloading:   9%|▉         | 66.1M/714M [00:05<00:55, 11.6MB/s]
# Downloading:   9%|▉         | 67.3M/714M [00:06<01:02, 10.3MB/s]
# Downloading:  10%|▉         | 68.9M/714M [00:06<00:54, 11.9MB/s]
# Downloading:  10%|▉         | 70.2M/714M [00:06<00:54, 11.8MB/s]
# Downloading:  10%|▉         | 71.4M/714M [00:06<00:54, 11.8MB/s]
# Downloading:  10%|█         | 72.6M/714M [00:06<00:55, 11.6MB/s]
# Downloading:  10%|█         | 73.7M/714M [00:06<00:55, 11.6MB/s]
# Downloading:  10%|█         | 74.9M/714M [00:06<00:55, 11.6MB/s]
# Downloading:  11%|█         | 76.1M/714M [00:06<01:02, 10.2MB/s]
# Downloading:  11%|█         | 77.7M/714M [00:06<00:53, 11.9MB/s]
# Downloading:  11%|█         | 79.0M/714M [00:07<00:53, 11.8MB/s]
# Downloading:  11%|█         | 80.2M/714M [00:07<01:01, 10.3MB/s]
# Downloading:  11%|█▏        | 81.9M/714M [00:07<00:52, 12.0MB/s]
# Downloading:  12%|█▏        | 83.1M/714M [00:07<00:53, 11.9MB/s]
# Downloading:  12%|█▏        | 84.4M/714M [00:07<00:53, 11.8MB/s]
# Downloading:  12%|█▏        | 85.6M/714M [00:07<00:56, 11.1MB/s]
# Downloading:  12%|█▏        | 86.9M/714M [00:07<00:53, 11.8MB/s]
# Downloading:  12%|█▏        | 88.1M/714M [00:07<00:53, 11.7MB/s]
# Downloading:  13%|█▎        | 89.3M/714M [00:07<01:00, 10.4MB/s]
# Downloading:  13%|█▎        | 91.0M/714M [00:08<00:52, 11.9MB/s]
# Downloading:  13%|█▎        | 92.2M/714M [00:08<00:52, 11.9MB/s]
# Downloading:  13%|█▎        | 93.4M/714M [00:08<01:00, 10.3MB/s]
# Downloading:  13%|█▎        | 95.1M/714M [00:08<00:51, 12.0MB/s]
# Downloading:  13%|█▎        | 96.4M/714M [00:08<00:51, 11.9MB/s]
# Downloading:  14%|█▎        | 97.7M/714M [00:08<00:51, 11.9MB/s]
# Downloading:  14%|█▍        | 98.9M/714M [00:08<00:54, 11.2MB/s]
# Downloading:  14%|█▍        | 100M/714M [00:08<00:52, 11.8MB/s]
# Downloading:  14%|█▍        | 101M/714M [00:08<00:52, 11.7MB/s]
# Downloading:  14%|█▍        | 103M/714M [00:09<00:59, 10.3MB/s]
# Downloading:  15%|█▍        | 104M/714M [00:09<00:51, 12.0MB/s]
# Downloading:  15%|█▍        | 105M/714M [00:09<00:51, 11.8MB/s]
# Downloading:  15%|█▍        | 107M/714M [00:09<00:58, 10.4MB/s]
# Downloading:  15%|█▌        | 108M/714M [00:09<00:50, 12.1MB/s]
# Downloading:  15%|█▌        | 110M/714M [00:09<00:50, 11.9MB/s]
# Downloading:  16%|█▌        | 111M/714M [00:09<00:51, 11.8MB/s]
# Downloading:  16%|█▌        | 112M/714M [00:09<00:53, 11.3MB/s]
# Downloading:  16%|█▌        | 113M/714M [00:10<00:51, 11.7MB/s]
# Downloading:  16%|█▌        | 115M/714M [00:10<00:51, 11.7MB/s]
# Downloading:  16%|█▌        | 116M/714M [00:10<00:58, 10.3MB/s]
# Downloading:  16%|█▋        | 117M/714M [00:10<00:50, 11.9MB/s]
# Downloading:  17%|█▋        | 119M/714M [00:10<00:50, 11.8MB/s]
# Downloading:  17%|█▋        | 120M/714M [00:10<01:30, 6.56MB/s]
# Downloading:  17%|█▋        | 121M/714M [00:11<01:19, 7.45MB/s]
# Downloading:  17%|█▋        | 122M/714M [00:11<01:19, 7.43MB/s]
# Downloading:  17%|█▋        | 124M/714M [00:11<01:02, 9.45MB/s]
# Downloading:  17%|█▋        | 125M/714M [00:11<00:59, 9.95MB/s]
# Downloading:  18%|█▊        | 126M/714M [00:11<00:56, 10.4MB/s]
# Downloading:  18%|█▊        | 127M/714M [00:11<00:58, 10.0MB/s]
# Downloading:  18%|█▊        | 129M/714M [00:11<00:52, 11.1MB/s]
# Downloading:  18%|█▊        | 130M/714M [00:11<00:52, 11.2MB/s]
# Downloading:  18%|█▊        | 131M/714M [00:11<00:58, 10.0MB/s]
# Downloading:  19%|█▊        | 133M/714M [00:12<00:49, 11.7MB/s]
# Downloading:  19%|█▊        | 134M/714M [00:12<00:49, 11.7MB/s]
# Downloading:  19%|█▉        | 135M/714M [00:12<00:49, 11.7MB/s]
# Downloading:  26%|██▌       | 187M/714M [00:16<00:44, 11.9MB/s]
# Downloading:  26%|██▋       | 188M/714M [00:16<00:44, 11.8MB/s]
# Downloading:  26%|██▋       | 189M/714M [00:16<00:46, 11.2MB/s]
# Downloading:  27%|██▋       | 191M/714M [00:17<00:44, 11.7MB/s]
# Downloading:  27%|██▋       | 192M/714M [00:17<00:44, 11.7MB/s]
# Downloading:  27%|██▋       | 193M/714M [00:17<00:50, 10.3MB/s]
# Downloading:  27%|██▋       | 195M/714M [00:17<00:43, 12.0MB/s]
# Downloading:  27%|██▋       | 196M/714M [00:17<00:43, 11.8MB/s]
# Downloading:  28%|██▊       | 197M/714M [00:17<00:43, 11.8MB/s]
# Downloading:  28%|██▊       | 198M/714M [00:17<00:45, 11.5MB/s]
# Downloading:  28%|██▊       | 200M/714M [00:17<00:44, 11.6MB/s]
# Downloading:  28%|██▊       | 201M/714M [00:17<00:44, 11.6MB/s]
# Downloading:  28%|██▊       | 202M/714M [00:18<00:50, 10.2MB/s]
# Downloading:  28%|██▊       | 204M/714M [00:18<00:42, 11.9MB/s]
# Downloading:  29%|██▊       | 205M/714M [00:18<00:43, 11.8MB/s]
# Downloading:  29%|██▉       | 206M/714M [00:18<00:43, 11.7MB/s]
# Downloading:  29%|██▉       | 207M/714M [00:18<00:44, 11.4MB/s]
# Downloading:  29%|██▉       | 208M/714M [00:18<00:43, 11.6MB/s]
# Downloading:  29%|██▉       | 210M/714M [00:18<00:43, 11.6MB/s]
# Downloading:  29%|██▉       | 211M/714M [00:18<00:49, 10.2MB/s]
# Downloading:  30%|██▉       | 212M/714M [00:18<00:42, 11.9MB/s]
# Downloading:  30%|██▉       | 214M/714M [00:19<00:42, 11.8MB/s]
# Downloading:  30%|███       | 215M/714M [00:19<00:48, 10.3MB/s]
# Downloading:  30%|███       | 216M/714M [00:19<00:41, 12.0MB/s]
# Downloading:  30%|███       | 218M/714M [00:19<00:41, 11.9MB/s]
# Downloading:  31%|███       | 219M/714M [00:19<00:41, 11.8MB/s]
# Downloading:  31%|███       | 220M/714M [00:19<00:44, 11.2MB/s]
# Downloading:  31%|███       | 222M/714M [00:19<00:42, 11.7MB/s]
# Downloading:  31%|███       | 223M/714M [00:19<00:42, 11.7MB/s]
# Downloading:  31%|███▏      | 224M/714M [00:20<00:47, 10.3MB/s]
# Downloading:  32%|███▏      | 226M/714M [00:20<00:40, 12.0MB/s]
# Downloading:  32%|███▏      | 227M/714M [00:20<00:41, 11.8MB/s]
# Downloading:  32%|███▏      | 228M/714M [00:20<00:41, 11.8MB/s]
# Downloading:  32%|███▏      | 229M/714M [00:20<00:41, 11.6MB/s]
# Downloading:  32%|███▏      | 230M/714M [00:20<00:41, 11.6MB/s]
# Downloading:  32%|███▏      | 232M/714M [00:20<00:41, 11.6MB/s]
# Downloading:  33%|███▎      | 233M/714M [00:20<00:47, 10.2MB/s]
# Downloading:  33%|███▎      | 234M/714M [00:20<00:40, 11.9MB/s]
# Downloading:  33%|███▎      | 236M/714M [00:20<00:40, 11.8MB/s]
# Downloading:  33%|███▎      | 237M/714M [00:21<00:40, 11.8MB/s]
# Downloading:  33%|███▎      | 238M/714M [00:21<01:14, 6.41MB/s]
# Downloading:  33%|███▎      | 239M/714M [00:21<01:04, 7.35MB/s]
# Downloading:  34%|███▎      | 240M/714M [00:21<01:02, 7.59MB/s]
# Downloading:  34%|███▍      | 242M/714M [00:21<00:51, 9.22MB/s]
# Downloading:  34%|███▍      | 243M/714M [00:21<00:48, 9.78MB/s]
# Downloading:  34%|███▍      | 244M/714M [00:22<00:51, 9.12MB/s]
# Downloading:  34%|███▍      | 246M/714M [00:22<00:42, 11.0MB/s]
# Downloading:  35%|███▍      | 247M/714M [00:22<00:41, 11.2MB/s]
# Downloading:  35%|███▍      | 248M/714M [00:22<00:41, 11.3MB/s]
# Downloading:  35%|███▍      | 249M/714M [00:22<00:42, 10.9MB/s]
# Downloading:  35%|███▌      | 251M/714M [00:22<00:40, 11.5MB/s]
# Downloading:  35%|███▌      | 252M/714M [00:22<00:40, 11.5MB/s]
# Downloading:  35%|███▌      | 253M/714M [00:22<00:45, 10.1MB/s]
# Downloading:  36%|███▌      | 255M/714M [00:22<00:38, 11.9MB/s]
# Downloading:  36%|███▌      | 256M/714M [00:23<00:38, 11.8MB/s]
# Downloading:  36%|███▌      | 257M/714M [00:23<00:38, 11.8MB/s]
# Downloading:  36%|███▌      | 258M/714M [00:23<00:40, 11.2MB/s]
# Downloading:  36%|███▋      | 260M/714M [00:23<00:38, 11.7MB/s]
# Downloading:  37%|███▋      | 261M/714M [00:23<00:38, 11.7MB/s]
# Downloading:  37%|███▋      | 262M/714M [00:23<00:43, 10.3MB/s]
# Downloading:  37%|███▋      | 264M/714M [00:23<00:37, 11.9MB/s]
# Downloading:  37%|███▋      | 265M/714M [00:23<00:37, 11.8MB/s]
# Downloading:  37%|███▋      | 266M/714M [00:23<00:43, 10.4MB/s]
# Downloading:  37%|███▋      | 268M/714M [00:24<00:37, 12.1MB/s]
# Downloading:  38%|███▊      | 269M/714M [00:24<00:37, 11.9MB/s]
# Downloading:  38%|███▊      | 270M/714M [00:24<00:37, 11.9MB/s]
# Downloading:  38%|███▊      | 272M/714M [00:24<00:39, 11.3MB/s]
# Downloading:  38%|███▊      | 273M/714M [00:24<00:37, 11.8MB/s]
# Downloading:  38%|███▊      | 274M/714M [00:24<00:37, 11.7MB/s]
# Downloading:  39%|███▊      | 275M/714M [00:24<00:42, 10.4MB/s]
# Downloading:  39%|███▉      | 277M/714M [00:24<00:36, 12.0MB/s]
# Downloading:  39%|███▉      | 278M/714M [00:24<00:36, 11.9MB/s]
# Downloading:  39%|███▉      | 279M/714M [00:25<00:42, 10.3MB/s]
# Downloading:  39%|███▉      | 281M/714M [00:25<00:35, 12.0MB/s]
# Downloading:  40%|███▉      | 282M/714M [00:25<00:36, 11.9MB/s]
# Downloading:  40%|███▉      | 284M/714M [00:25<00:36, 11.8MB/s]
# Downloading:  40%|███▉      | 285M/714M [00:25<00:37, 11.5MB/s]
# Downloading:  40%|████      | 286M/714M [00:25<00:36, 11.6MB/s]
# Downloading:  40%|████      | 287M/714M [00:25<00:36, 11.6MB/s]
# Downloading:  48%|████▊     | 340M/714M [00:30<00:31, 11.7MB/s]
# Downloading:  48%|████▊     | 341M/714M [00:30<00:36, 10.3MB/s]
# Downloading:  48%|████▊     | 343M/714M [00:30<00:31, 12.0MB/s]
# Downloading:  48%|████▊     | 344M/714M [00:30<00:31, 11.9MB/s]
# Downloading:  48%|████▊     | 346M/714M [00:30<00:31, 11.8MB/s]
# Downloading:  49%|████▊     | 347M/714M [00:30<00:31, 11.5MB/s]
# Downloading:  49%|████▊     | 348M/714M [00:31<00:31, 11.6MB/s]
# Downloading:  49%|████▉     | 349M/714M [00:31<00:31, 11.6MB/s]
# Downloading:  49%|████▉     | 350M/714M [00:31<00:35, 10.3MB/s]
# Downloading:  49%|████▉     | 352M/714M [00:31<00:30, 11.9MB/s]
# Downloading:  49%|████▉     | 353M/714M [00:31<00:54, 6.60MB/s]
# Downloading:  50%|████▉     | 354M/714M [00:31<00:53, 6.78MB/s]
# Downloading:  50%|████▉     | 356M/714M [00:32<00:41, 8.70MB/s]
# Downloading:  50%|████▉     | 357M/714M [00:32<00:38, 9.32MB/s]
# Downloading:  50%|█████     | 358M/714M [00:32<00:36, 9.88MB/s]
# Downloading:  50%|█████     | 359M/714M [00:32<00:36, 9.81MB/s]
# Downloading:  50%|█████     | 361M/714M [00:32<00:32, 10.8MB/s]
# Downloading:  51%|█████     | 362M/714M [00:32<00:32, 11.0MB/s]
# Downloading:  51%|█████     | 363M/714M [00:32<00:35, 9.87MB/s]
# Downloading:  51%|█████     | 365M/714M [00:32<00:30, 11.6MB/s]
# Downloading:  51%|█████     | 366M/714M [00:32<00:29, 11.7MB/s]
# Downloading:  51%|█████▏    | 367M/714M [00:33<00:33, 10.2MB/s]
# Downloading:  52%|█████▏    | 369M/714M [00:33<00:28, 12.0MB/s]
# Downloading:  52%|█████▏    | 370M/714M [00:33<00:28, 11.9MB/s]
# Downloading:  52%|█████▏    | 371M/714M [00:33<00:29, 11.8MB/s]
# Downloading:  52%|█████▏    | 373M/714M [00:33<00:30, 11.1MB/s]
# Downloading:  52%|█████▏    | 374M/714M [00:33<00:28, 11.8MB/s]
# Downloading:  53%|█████▎    | 375M/714M [00:33<00:28, 11.7MB/s]
# Downloading:  53%|█████▎    | 376M/714M [00:33<00:32, 10.4MB/s]
# Downloading:  53%|█████▎    | 378M/714M [00:33<00:28, 11.9MB/s]
# Downloading:  53%|█████▎    | 379M/714M [00:34<00:28, 11.9MB/s]
# Downloading:  53%|█████▎    | 380M/714M [00:34<00:32, 10.4MB/s]
# Downloading:  53%|█████▎    | 382M/714M [00:34<00:27, 12.0MB/s]
# Downloading:  54%|█████▎    | 383M/714M [00:34<00:27, 11.9MB/s]
# Downloading:  54%|█████▍    | 385M/714M [00:34<00:27, 11.8MB/s]
# Downloading:  54%|█████▍    | 386M/714M [00:34<00:29, 11.2MB/s]
# Downloading:  54%|█████▍    | 387M/714M [00:34<00:27, 11.8MB/s]
# Downloading:  54%|█████▍    | 388M/714M [00:34<00:27, 11.7MB/s]
# Downloading:  55%|█████▍    | 390M/714M [00:35<00:31, 10.3MB/s]
# Downloading:  55%|█████▍    | 391M/714M [00:35<00:27, 11.9MB/s]
# Downloading:  55%|█████▍    | 392M/714M [00:35<00:27, 11.8MB/s]
# Downloading:  55%|█████▌    | 394M/714M [00:35<00:27, 11.8MB/s]
# Downloading:  55%|█████▌    | 395M/714M [00:35<00:27, 11.6MB/s]
# Downloading:  55%|█████▌    | 396M/714M [00:35<00:27, 11.6MB/s]
# Downloading:  56%|█████▌    | 397M/714M [00:35<00:27, 11.6MB/s]
# Downloading:  56%|█████▌    | 398M/714M [00:35<00:30, 10.2MB/s]
# Downloading:  56%|█████▌    | 400M/714M [00:35<00:26, 11.9MB/s]
# Downloading:  56%|█████▌    | 401M/714M [00:35<00:26, 11.8MB/s]
# Downloading:  56%|█████▋    | 402M/714M [00:36<00:26, 11.8MB/s]
# Downloading:  57%|█████▋    | 404M/714M [00:36<00:27, 11.5MB/s]
# Downloading:  57%|█████▋    | 405M/714M [00:36<00:26, 11.6MB/s]
# Downloading:  57%|█████▋    | 406M/714M [00:36<00:26, 11.6MB/s]
# Downloading:  57%|█████▋    | 407M/714M [00:36<00:30, 10.2MB/s]
# Downloading:  57%|█████▋    | 409M/714M [00:36<00:25, 11.9MB/s]
# Downloading:  57%|█████▋    | 410M/714M [00:36<00:25, 11.8MB/s]
# Downloading:  58%|█████▊    | 411M/714M [00:36<00:29, 10.3MB/s]
# Downloading:  58%|█████▊    | 413M/714M [00:37<00:25, 12.0MB/s]
# Downloading:  58%|█████▊    | 414M/714M [00:37<00:25, 11.9MB/s]
# Downloading:  58%|█████▊    | 416M/714M [00:37<00:25, 11.8MB/s]
# Downloading:  58%|█████▊    | 417M/714M [00:37<00:26, 11.4MB/s]
# Downloading:  59%|█████▊    | 418M/714M [00:37<00:25, 11.7MB/s]
# Downloading:  59%|█████▊    | 419M/714M [00:37<00:25, 11.7MB/s]
# Downloading:  59%|█████▉    | 420M/714M [00:37<00:28, 10.2MB/s]
# Downloading:  59%|█████▉    | 422M/714M [00:37<00:24, 11.9MB/s]
# Downloading:  59%|█████▉    | 423M/714M [00:37<00:24, 11.8MB/s]
# Downloading:  59%|█████▉    | 424M/714M [00:38<00:24, 11.8MB/s]
# Downloading:  60%|█████▉    | 426M/714M [00:38<00:25, 11.2MB/s]
# Downloading:  60%|█████▉    | 427M/714M [00:38<00:24, 11.7MB/s]
# Downloading:  60%|█████▉    | 428M/714M [00:38<00:24, 11.7MB/s]
# Downloading:  60%|██████    | 429M/714M [00:38<00:27, 10.3MB/s]
# Downloading:  60%|██████    | 431M/714M [00:38<00:23, 11.9MB/s]
# Downloading:  61%|██████    | 432M/714M [00:38<00:23, 11.8MB/s]
# Downloading:  61%|██████    | 433M/714M [00:38<00:27, 10.3MB/s]
# Downloading:  61%|██████    | 435M/714M [00:38<00:23, 12.0MB/s]
# Downloading:  61%|██████    | 436M/714M [00:39<00:23, 11.9MB/s]
# Downloading:  61%|██████▏   | 438M/714M [00:39<00:23, 11.8MB/s]
# Downloading:  61%|██████▏   | 439M/714M [00:39<00:24, 11.3MB/s]
# Downloading:  62%|██████▏   | 440M/714M [00:39<00:23, 11.7MB/s]
# Downloading:  76%|███████▌  | 541M/714M [00:48<00:14, 11.8MB/s]
# Downloading:  76%|███████▌  | 542M/714M [00:48<00:16, 10.4MB/s]
# Downloading:  76%|███████▌  | 544M/714M [00:48<00:14, 12.0MB/s]
# Downloading:  76%|███████▋  | 545M/714M [00:48<00:14, 11.9MB/s]
# Downloading:  76%|███████▋  | 546M/714M [00:48<00:16, 10.4MB/s]
# Downloading:  77%|███████▋  | 548M/714M [00:49<00:13, 12.0MB/s]
# Downloading:  77%|███████▋  | 549M/714M [00:49<00:13, 11.9MB/s]
# Downloading:  77%|███████▋  | 550M/714M [00:49<00:13, 11.8MB/s]
# Downloading:  77%|███████▋  | 552M/714M [00:49<00:14, 11.5MB/s]
# Downloading:  77%|███████▋  | 553M/714M [00:49<00:13, 11.7MB/s]
# Downloading:  78%|███████▊  | 554M/714M [00:49<00:13, 11.6MB/s]
# Downloading:  78%|███████▊  | 555M/714M [00:49<00:15, 10.2MB/s]
# Downloading:  78%|███████▊  | 557M/714M [00:49<00:13, 11.9MB/s]
# Downloading:  78%|███████▊  | 558M/714M [00:49<00:13, 11.9MB/s]
# Downloading:  78%|███████▊  | 559M/714M [00:50<00:13, 11.8MB/s]
# Downloading:  78%|███████▊  | 561M/714M [00:50<00:13, 11.4MB/s]
# Downloading:  79%|███████▊  | 562M/714M [00:50<00:13, 11.7MB/s]
# Downloading:  79%|███████▉  | 563M/714M [00:50<00:13, 11.6MB/s]
# Downloading:  79%|███████▉  | 564M/714M [00:50<00:14, 10.2MB/s]
# Downloading:  79%|███████▉  | 566M/714M [00:50<00:12, 11.9MB/s]
# Downloading:  79%|███████▉  | 567M/714M [00:50<00:12, 11.9MB/s]
# Downloading:  80%|███████▉  | 568M/714M [00:50<00:12, 11.8MB/s]
# Downloading:  80%|███████▉  | 570M/714M [00:50<00:12, 11.4MB/s]
# Downloading:  80%|███████▉  | 571M/714M [00:51<00:12, 11.6MB/s]
# Downloading:  80%|████████  | 572M/714M [00:51<00:12, 11.6MB/s]
# Downloading:  80%|████████  | 573M/714M [00:51<00:13, 10.2MB/s]
# Downloading:  80%|████████  | 575M/714M [00:51<00:11, 11.9MB/s]
# Downloading:  81%|████████  | 576M/714M [00:51<00:11, 11.8MB/s]
# Downloading:  81%|████████  | 577M/714M [00:51<00:11, 11.8MB/s]
# Downloading:  81%|████████  | 578M/714M [00:51<00:11, 11.6MB/s]
# Downloading:  81%|████████  | 580M/714M [00:51<00:11, 11.6MB/s]
# Downloading:  81%|████████▏ | 581M/714M [00:51<00:11, 11.6MB/s]
# Downloading:  81%|████████▏ | 582M/714M [00:52<00:13, 10.2MB/s]
# Downloading:  82%|████████▏ | 584M/714M [00:52<00:10, 11.9MB/s]
# Downloading:  82%|████████▏ | 585M/714M [00:52<00:10, 11.8MB/s]
# Downloading:  82%|████████▏ | 586M/714M [00:52<00:10, 11.8MB/s]
# Downloading:  82%|████████▏ | 587M/714M [00:52<00:18, 6.75MB/s]
# Downloading:  82%|████████▏ | 588M/714M [00:52<00:18, 6.86MB/s]
# Downloading:  83%|████████▎ | 590M/714M [00:52<00:14, 8.89MB/s]
# Downloading:  83%|████████▎ | 591M/714M [00:53<00:12, 9.49MB/s]
# Downloading:  83%|████████▎ | 592M/714M [00:53<00:12, 10.0MB/s]
# Downloading:  83%|████████▎ | 593M/714M [00:53<00:12, 9.69MB/s]
# Downloading:  83%|████████▎ | 595M/714M [00:53<00:10, 10.9MB/s]
# Downloading:  83%|████████▎ | 596M/714M [00:53<00:10, 11.1MB/s]
# Downloading:  84%|████████▎ | 597M/714M [00:53<00:11, 9.94MB/s]
# Downloading:  84%|████████▍ | 599M/714M [00:53<00:09, 11.7MB/s]
# Downloading:  84%|████████▍ | 600M/714M [00:53<00:09, 11.7MB/s]
# Downloading:  84%|████████▍ | 601M/714M [00:53<00:09, 11.6MB/s]
# Downloading:  84%|████████▍ | 602M/714M [00:54<00:09, 11.2MB/s]
# Downloading:  85%|████████▍ | 604M/714M [00:54<00:09, 11.6MB/s]
# Downloading:  85%|████████▍ | 605M/714M [00:54<00:09, 11.6MB/s]
# Downloading:  85%|████████▍ | 606M/714M [00:54<00:10, 10.3MB/s]
# Downloading:  85%|████████▌ | 608M/714M [00:54<00:08, 11.9MB/s]
# Downloading:  85%|████████▌ | 609M/714M [00:54<00:08, 11.8MB/s]
# Downloading:  85%|████████▌ | 610M/714M [00:54<00:10, 10.3MB/s]
# Downloading:  86%|████████▌ | 612M/714M [00:54<00:08, 12.0MB/s]
# Downloading:  86%|████████▌ | 613M/714M [00:55<00:08, 11.9MB/s]
# Downloading:  86%|████████▌ | 614M/714M [00:55<00:08, 11.8MB/s]
# Downloading:  86%|████████▌ | 616M/714M [00:55<00:08, 11.1MB/s]
# Downloading:  86%|████████▋ | 617M/714M [00:55<00:08, 11.8MB/s]
# Downloading:  87%|████████▋ | 618M/714M [00:55<00:08, 11.7MB/s]
# Downloading:  87%|████████▋ | 619M/714M [00:55<00:09, 10.3MB/s]
# Downloading:  87%|████████▋ | 621M/714M [00:55<00:07, 11.9MB/s]
# Downloading:  87%|████████▋ | 622M/714M [00:55<00:07, 11.8MB/s]
# Downloading:  87%|████████▋ | 623M/714M [00:55<00:07, 11.8MB/s]
# Downloading:  87%|████████▋ | 625M/714M [00:56<00:07, 11.4MB/s]
# Downloading:  88%|████████▊ | 626M/714M [00:56<00:07, 11.7MB/s]
# Downloading:  88%|████████▊ | 627M/714M [00:56<00:07, 11.6MB/s]
# Downloading:  88%|████████▊ | 628M/714M [00:56<00:08, 10.3MB/s]
# Downloading:  88%|████████▊ | 630M/714M [00:56<00:07, 11.9MB/s]
# Downloading:  88%|████████▊ | 631M/714M [00:56<00:07, 11.8MB/s]
# Downloading:  89%|████████▊ | 632M/714M [00:56<00:07, 10.3MB/s]
# Downloading:  89%|████████▉ | 634M/714M [00:56<00:06, 12.0MB/s]
# Downloading:  89%|████████▉ | 635M/714M [00:56<00:06, 11.9MB/s]
# Downloading:  89%|████████▉ | 637M/714M [00:57<00:06, 11.8MB/s]
# Downloading:  89%|████████▉ | 638M/714M [00:57<00:06, 11.1MB/s]
# Downloading:  89%|████████▉ | 639M/714M [00:57<00:06, 11.8MB/s]
# Downloading:  90%|████████▉ | 640M/714M [00:57<00:06, 11.7MB/s]
# Downloading:  90%|████████▉ | 642M/714M [00:57<00:07, 10.4MB/s]
# Downloading:  90%|█████████ | 643M/714M [00:57<00:05, 11.9MB/s]
# Downloading:  90%|█████████ | 644M/714M [00:57<00:05, 11.9MB/s]
# Downloading:  90%|█████████ | 646M/714M [00:57<00:06, 10.4MB/s]
# Downloading:  91%|█████████ | 647M/714M [00:57<00:05, 12.0MB/s]
# Downloading:  91%|█████████ | 649M/714M [00:58<00:05, 11.9MB/s]
# Downloading:  91%|█████████ | 650M/714M [00:58<00:05, 11.8MB/s]
# Downloading:  91%|█████████ | 651M/714M [00:58<00:05, 11.2MB/s]
# Downloading:  91%|█████████▏| 652M/714M [00:58<00:05, 11.7MB/s]
# Downloading:  91%|█████████▏| 654M/714M [00:58<00:05, 11.7MB/s]
# Downloading:  92%|█████████▏| 655M/714M [00:58<00:05, 10.3MB/s]
# Downloading:  92%|█████████▏| 656M/714M [00:58<00:04, 11.9MB/s]
# Downloading:  92%|█████████▏| 658M/714M [00:58<00:04, 11.8MB/s]
# Downloading:  92%|█████████▏| 659M/714M [00:59<00:05, 10.3MB/s]
# Downloading:  92%|█████████▏| 661M/714M [00:59<00:04, 12.0MB/s]
# Downloading:  93%|█████████▎| 662M/714M [00:59<00:04, 11.9MB/s]
# Downloading:  93%|█████████▎| 663M/714M [00:59<00:04, 11.8MB/s]
# Downloading:  93%|█████████▎| 664M/714M [00:59<00:04, 11.3MB/s]
# Downloading:  93%|█████████▎| 666M/714M [00:59<00:04, 11.7MB/s]
# Downloading:  93%|█████████▎| 667M/714M [00:59<00:04, 11.7MB/s]
# Downloading:  94%|█████████▎| 668M/714M [00:59<00:04, 10.3MB/s]
# Downloading:  94%|█████████▎| 670M/714M [00:59<00:03, 11.9MB/s]
# Downloading:  94%|█████████▍| 671M/714M [01:00<00:03, 11.9MB/s]
# Downloading:  94%|█████████▍| 672M/714M [01:00<00:03, 11.8MB/s]
# Downloading:  94%|█████████▍| 673M/714M [01:00<00:03, 11.5MB/s]
# Downloading:  94%|█████████▍| 675M/714M [01:00<00:03, 11.6MB/s]
# Downloading:  95%|█████████▍| 676M/714M [01:00<00:03, 11.6MB/s]
# Downloading:  95%|█████████▍| 677M/714M [01:00<00:03, 10.3MB/s]
# Downloading:  95%|█████████▍| 679M/714M [01:00<00:03, 11.9MB/s]
# Downloading:  95%|█████████▌| 680M/714M [01:00<00:02, 11.8MB/s]
# Downloading:  95%|█████████▌| 681M/714M [01:00<00:02, 11.8MB/s]
# Downloading:  95%|█████████▌| 682M/714M [01:01<00:02, 11.4MB/s]
# Downloading:  96%|█████████▌| 683M/714M [01:01<00:02, 11.6MB/s]
# Downloading:  96%|█████████▌| 685M/714M [01:01<00:02, 11.7MB/s]
# Downloading:  96%|█████████▌| 686M/714M [01:01<00:02, 10.3MB/s]
# Downloading:  96%|█████████▌| 687M/714M [01:01<00:02, 11.9MB/s]
# Downloading:  96%|█████████▋| 689M/714M [01:01<00:02, 11.8MB/s]
# Downloading:  97%|█████████▋| 690M/714M [01:01<00:02, 10.3MB/s]
# Downloading:  97%|█████████▋| 692M/714M [01:01<00:01, 12.0MB/s]
# Downloading:  97%|█████████▋| 693M/714M [01:01<00:01, 11.9MB/s]
# Downloading:  97%|█████████▋| 694M/714M [01:02<00:01, 11.9MB/s]
# Downloading:  97%|█████████▋| 695M/714M [01:02<00:01, 11.2MB/s]
# Downloading:  98%|█████████▊| 697M/714M [01:02<00:01, 11.8MB/s]
# Downloading:  98%|█████████▊| 698M/714M [01:02<00:01, 11.7MB/s]
# Downloading:  98%|█████████▊| 699M/714M [01:02<00:01, 10.3MB/s]
# Downloading:  98%|█████████▊| 701M/714M [01:02<00:01, 12.0MB/s]
# Downloading:  98%|█████████▊| 702M/714M [01:02<00:01, 11.9MB/s]
# Downloading:  98%|█████████▊| 703M/714M [01:03<00:01, 6.56MB/s]
# Downloading:  99%|█████████▊| 704M/714M [01:03<00:01, 6.89MB/s]
# Downloading:  99%|█████████▉| 706M/714M [01:03<00:01, 8.53MB/s]
# Downloading:  99%|█████████▉| 707M/714M [01:03<00:00, 9.21MB/s]
# Downloading:  99%|█████████▉| 708M/714M [01:03<00:00, 8.73MB/s]
# Downloading:  99%|█████████▉| 710M/714M [01:03<00:00, 10.7MB/s]
# Downloading: 100%|█████████▉| 711M/714M [01:03<00:00, 10.9MB/s]
# Downloading: 100%|█████████▉| 712M/714M [01:03<00:00, 11.1MB/s]
# Downloading: 100%|██████████| 714M/714M [01:04<00:00, 11.1MB/s]
#
# Downloading: 100%|██████████| 112/112 [00:00<00:00, 712kB/s]
#
# Downloading: 100%|██████████| 24.0/24.0 [00:00<00:00, 82.1kB/s]
#
# Downloading:   0%|          | 0.00/1.65M [00:00<?, ?B/s]
# Downloading:   4%|▍         | 66.6k/1.65M [00:00<00:02, 609kB/s]
# Downloading:  12%|█▏        | 206k/1.65M [00:00<00:01, 994kB/s]
# Downloading:  30%|██▉       | 493k/1.65M [00:00<00:00, 1.72MB/s]
# Downloading:  65%|██████▍   | 1.07M/1.65M [00:00<00:00, 3.06MB/s]
# Downloading: 100%|██████████| 1.65M/1.65M [00:00<00:00, 2.95MB/s]
# WARNING:root:No sentence-transformers model found with name /home/matvey/.cache/torch/sentence_transformers/DeepPavlov_rubert-base-cased. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at /home/matvey/.cache/torch/sentence_transformers/DeepPavlov_rubert-base-cased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
@dataclass
class User:
    user_id: int
    about_me: str
    selected_interests: List[int]

def get_user_embeddings(user_selected_interests: List[int], embeddings: Dict[str, List[float]]) -> np.ndarray:
    return np.array([embeddings[str(interest_id)] for interest_id in user_selected_interests])

def calculate_interest_similarity(user1_selected_interests: List[int], user2_selected_interests: List[int]) -> float:
    user1_embeddings = get_user_embeddings(user1_selected_interests, interest_embeddings)
    user2_embeddings = get_user_embeddings(user2_selected_interests, interest_embeddings)
    user1_embeddings = normalize(user1_embeddings)
    user2_embeddings = normalize(user2_embeddings)

    similarities = [cosine_similarity([emb1], [emb2])[0][0] for emb1 in user1_embeddings for emb2 in user2_embeddings]
    return np.mean(similarities)

def extract_entities_and_embeddings(text: str) -> Tuple[Dict[str, List[str]], Dict[str, List[np.ndarray]]]:
    doc = nlp(text)
    entities = {ent_type: [] for ent_type in ["PER", "ORG", "LOC", "MISC", "GPE", "FAC", "NORP", "EVENT", "WORK_OF_ART", "LAW", "LANGUAGE"]}
    embeddings = {ent_type: [] for ent_type in ["PER", "ORG", "LOC", "MISC", "GPE", "FAC", "NORP", "EVENT", "WORK_OF_ART", "LAW", "LANGUAGE"]}

    for sentence in doc.sentences:
        for ent in sentence.ents:
            if ent.type in entities:
                entities[ent.type].append(ent.text)
                entity_embedding = model.encode([ent.text])[0]
                embeddings[ent.type].append(entity_embedding)

    return entities, embeddings

def calculate_description_similarity(user1_about_me: str, user2_about_me: str) -> float:
    entities1, embeddings1 = extract_entities_and_embeddings(user1_about_me)
    entities2, embeddings2 = extract_entities_and_embeddings(user2_about_me)

    all_similarities = []
    for category in entities1:
        category1 = entities1[category]
        embeddings1_category = embeddings1.get(category, [])
        
        category2 = entities2.get(category, [])
        embeddings2_category = embeddings2.get(category, [])

        for ent1, emb1 in zip(category1, embeddings1_category):
            for ent2, emb2 in zip(category2, embeddings2_category):
                similarity = cosine_similarity([emb1], [emb2])[0][0]
                all_similarities.append(similarity)

    return np.mean(all_similarities) if all_similarities else 0.0

def calculate_total_relevance(interest_similarity: float, description_similarity: float) -> float:
    return 0.8 * interest_similarity + 0.2 * description_similarity

def compare_users(user1: User, user2: User) -> float:
    interest_similarity = calculate_interest_similarity(user1.selected_interests, user2.selected_interests)
    description_similarity = calculate_description_similarity(user1.about_me, user2.about_me)
    return calculate_total_relevance(interest_similarity, description_similarity)

def compare_user_with_group(user: User, users: List[User]) -> List[Tuple[int, float]]:
    relevance_scores = []
    for other_user in users:
        if user.user_id != other_user.user_id:
            relevance_score = compare_users(user, other_user)
            relevance_scores.append((other_user.user_id, relevance_score))
    return sorted(relevance_scores, key=lambda x: x[1], reverse=True)

# %%
# Пример данных
user1 = User(
    user_id=1,
    about_me="РОССИЯ ЗОВ ГОЙДА",
    selected_interests=["1", "2"]
)

user2 = User(
    user_id=2,
    about_me="ВОДКА БАЛАЛАЙКА",
    selected_interests=["2", "3"]
)

user3 = User(
    user_id=3,
    about_me="Африка негры",
    selected_interests=["1","4"]
)

# Пример списка пользователей
users = [user1, user2, user3]

# Пример вызова функции для сравнения двух пользователей
interest_similarity = calculate_interest_similarity(user1.selected_interests, user2.selected_interests)
print(f"Interest Similarity between User 1 and User 2: {interest_similarity:.4f}")

# Пример вызова функции для сравнения описаний двух пользователей
description_similarity = calculate_description_similarity(user1.about_me, user2.about_me)
print(f"Description Similarity between User 1 and User 2: {description_similarity:.4f}")

# Пример сравнения одного пользователя с группой
relevance_scores = compare_user_with_group(user1, users)
print("\nRelevance Scores for User 1 with others:")
for user_id, score in relevance_scores:
    print(f"User {user_id}: {score:.4f}")

# Пример вычисления общей релевантности для двух пользователей
total_relevance = compare_users(user1, user2)
print(f"\nTotal Relevance between User 1 and User 2: {total_relevance:.4f}")
# Out:
# Interest Similarity between User 1 and User 2: 0.7114
# Description Similarity between User 1 and User 2: 0.6511
#
# Relevance Scores for User 1 with others:
# User 3: 0.7037
# User 2: 0.6994
#
# Total Relevance between User 1 and User 2: 0.6994
